# %%
a=10
if(a!=10):
    print(a)

# %%
a=9
if(a!=10):
    print(a)
# Out:
# 9

# %%
# Out:
# 10

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ab1b269cf753> in <module>
# ----> 1 a="my name yamini"+21
#       2 print(a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
import seaborn as sb

# %%
print(sb.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
ds=sb.load_dataset("exercise")

# %%
ds
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
ds.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
ds.describe()
# Out:
#        Unnamed: 0         id       pulse
# count   90.000000  90.000000   90.000000
# mean    44.500000  15.500000   99.700000
# std     26.124701   8.703932   14.858471
# min      0.000000   1.000000   80.000000
# 25%     22.250000   8.000000   90.250000
# 50%     44.500000  15.500000   96.000000
# 75%     66.750000  23.000000  103.000000
# max     89.000000  30.000000  150.000000

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     int64
#  1   id          90 non-null     int64
#  2   diet        90 non-null     category
#  3   pulse       90 non-null     int64
#  4   time        90 non-null     category
#  5   kind        90 non-null     category
# dtypes: category(3), int64(3)
# memory usage: 2.8 KB

# %%
sb.relplot(data=ds,x="id",y="pulse",hue="kind")

# %%
sb.relplot(data=ds,x="id",y="pulse",col="kind",col_wrap=3)

# %%
sb.relplot(data=ds,x="id",y="pulse")

# %%
sb.displot(ds.pulse)

# %%
sb.barplot(data=ds,x="kind",y="pulse")
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
sb.barplot(data=ds,x="kind",y="pulse",hue="diet")
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
sb.relplot(data=ds,x="id",y="pulse",col="kind",col_wrap=3)

# %%
sb.displot(ds.pulse,kde=False)

# %%
sb.barplot(data=ds,x="kind",y="pulse")
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
sb.countplot(data=ds,x="diet")
# Out:
# <AxesSubplot:xlabel='diet', ylabel='count'>

# %%
sb.jointplot(data=ds,x="pulse",y="id")

# %%
sb.boxplot(x="kind",y="pulse",data=ds)
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
corr=ds.corr()

# %%
corr
# Out:
#             Unnamed: 0        id     pulse
# Unnamed: 0    1.000000  0.999506  0.688489
# id            0.999506  1.000000  0.679012
# pulse         0.688489  0.679012  1.000000

# %%
sb.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
sb.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sb.heatmap(corr,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sb.pairplot(data=ds)

# %%
sb.pairplot(data=ds,hue="diet",kind="scatter",palette="husl")
